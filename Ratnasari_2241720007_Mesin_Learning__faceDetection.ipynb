# %% [markdown]
# <a href="https://colab.research.google.com/github/Ratnasari124/Mechine_Learning_Ratnasari/blob/main/Ratnasari_2241720007_Mesin_Learning__faceDetection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Face Detection**
#
#
# ---
#
#
# Nama : Ratnasari
#
# Kelas : TI 3D
#
# NIM : 2241720007
#
# Absen : 25
#
# ---
#
# Link Github : https://github.com/Ratnasari124/Mechine_Learning_Ratnasari/blob/main/Ratnasari_2241720007_Mesin_Learning__faceDetection.ipynb

# %%
import cv2

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
imagePath = "/content/drive/MyDrive/ratna/female.jpg"

# %%
img = cv2.imread(imagePath)

# %%
img.shape
# Out:
# (128, 128, 3)

# %%
gray_image = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# %%
gray_image.shape
# Out:
# (128, 128)

# %%
face_classifier = cv2.CascadeClassifier('/content/drive/MyDrive/ratna/Images/haarcascades/haarcascade_frontalface_alt.xml')

# %%
face = face_classifier.detectMultiScale(
    gray_image, scaleFactor=1.1, minNeighbors=5, minSize=(40, 40)
)

# %%
for (x, y, w, h) in face:
    cv2.rectangle(img, (x, y), (x + w, y + h), (0, 255, 0), 4)

# %%
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
import matplotlib.pyplot as plt



plt.figure(figsize=(20,10))
plt.imshow(img_rgb)
plt.axis('off')
# Out:
# (-0.5, 127.5, 127.5, -0.5)
